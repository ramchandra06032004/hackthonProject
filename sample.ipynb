# %%
import pandas as pd

# %%
df=pd.read_csv('streamlit_app/required_dataframe/yearWiseAccident.csv')
df
# Out:
#     Years  Total Number of Road Accidents (in numbers)   Road Length (in kms)  \
# 0    1970                                      114100.0             1188728.0
# 1    1980                                      153200.0             1491873.0
# 2    1990                                      282600.0             1983867.0
# 3    1994                                      325864.0             2890950.0
# 4    1995                                      351999.0             2975035.0
# 5    1996                                      371204.0             3202515.0
# 6    1997                                      373671.0             3298788.0
# 7    1998                                      385018.0             3228356.0
# 8    1999                                      386456.0             3296650.0
# 9    2000                                      391449.0             3316078.0
# 10   2001                                      405637.0             3373520.0
# ...
